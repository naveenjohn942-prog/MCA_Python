# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
calo=pd.read_csv('nutrients_csvfile.csv')
calo.head(10)
# Out:
#     User_ID  Gender   Age  Height  Weight                   Food     Measure  \
# 0  14733363    male   NaN     190      94             Cows' milk       1 qt.
# 1  14861698  female  20.0     166      60              Milk skim       1 qt.
# 2  11179863    male   NaN     179      79             Buttermilk       1 cup
# 3  16180408  female  34.0     179      71  Evaporated, undiluted       1 cup
# 4  17771927  female   NaN     154      58         Fortified milk      6 cups
# 5  15130815  female  36.0     151      50          Powdered milk       1 cup
# 6  19602372  female  33.0     158      56          skim, instant  1 1/3 cups
# 7  11117088    male   NaN     175      85      skim, non-instant     2/3 cup
# 8  12132339    male  60.0     186      94            Goats' milk       1 cup
# 9  17964668  female  26.0     146      51    (1/2 cup ice cream)      2 cups
#
#    Grams Calories Protein Fat Sat.Fat Fiber Carbs        Category  Rating  \
# ...

# %%
calo['Category'].unique()
dp = calo[calo['Category'] == 'Dairy products']

# %%
dp["Calories"] = pd.to_numeric(dp["Calories"], errors="coerce")
dp["Calories"].plot(kind="hist", label="Calories", color='b', fontsize=10, density=True)

plt.title('Histogram of Grams in Dairy Products')
plt.xlabel('Calories')

plt.show()
# Out:
# /tmp/ipykernel_46900/3258560730.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp["Calories"] = pd.to_numeric(dp["Calories"], errors="coerce")

# %%
dp.plot(x="Calories", y="Protein", kind="scatter",label='Calories',color='r')
plt.title('Scatter Plot - Setosa')
plt.xlabel('Calories')
plt.ylabel('Protein')
plt.show()

# %%
dp["Calories"].plot(kind="line",label='Calories',color='black',linewidth='1.5',ls='-')

plt.axis([0,50,2,1000])
plt.title('Line Plot')
plt.xlabel('Calories')
plt.show()

# %%
dp=dp.drop(columns="User_ID")

# %%
#area plot
dp.plot.area(stacked=False)
plt.show()
dp.describe()
# Out:
#              Age      Height     Weight    Calories     Rating
# count  24.000000   28.000000  28.000000   27.000000  25.000000
# mean   38.375000  170.500000  71.178571  261.518519   4.328000
# std    13.389849   13.628673  14.460812  159.928679   0.385703
# min    20.000000  146.000000  50.000000   70.000000   3.200000
# 25%    30.500000  157.000000  58.750000  139.000000   4.100000
# 50%    35.000000  172.000000  72.000000  235.000000   4.400000
# 75%    46.500000  182.000000  85.000000  295.000000   4.600000
# max    67.000000  190.000000  94.000000  690.000000   4.800000

# %%
#bargraph
calo['Calories'] = pd.to_numeric(calo['Calories'], errors='coerce')

Type=list(calo['Category'].unique())
count=list(calo['Category'].value_counts())
Avg=list(calo.groupby('Category')["Calories"].mean())
plt.bar(Type, Avg, color=['maroon', 'yellow', 'blue', 'green', 'purple', 'orange', 'red'],width=0.4)
plt.title('Bar Plot')

plt.xlabel('Calories')
plt.ylabel('AverageCalories')
plt.xticks(rotation=90)

plt.show()

# %%
#pie chart
ethnic_group_counts = dp['Calories'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(ethnic_group_counts, labels=ethnic_group_counts.index, autopct='%1.2f%%', startangle=140)
plt.title('Calories')
plt.axis('equal') 
plt.show()

# %%
#box plot
dp.plot.box()
plt.title("Box Plot")
plt.legend(labels = ['Calories','Grams','Carbs','Protein'])

plt.show()

# %%
import seaborn as sns
sns.set(style="white")
sns.pairplot(dp, hue="Category")
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#violen graph
plt.figure(figsize=(10, 6))
sns.violinplot(x='Gender', y='Calories', data=dp, palette='muted')
plt.title('Violin Plot of Calories by Gender')
plt.xlabel('Gender')
plt.ylabel('Calories')
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
